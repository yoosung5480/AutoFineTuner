# %%
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from openai import OpenAI
#       2 import json
# ----> 3 client = OpenAI()
#       5 tools = [{
#       6   "type": "function",
#       7   "function": {
#    (...)
#      16   }
#      17 }]
#      19 resp = client.chat.completions.create(
#      20   model="gpt-4o",
#      21   messages=[
#    (...)
#      26   tool_choice={"type":"function","function":{"name":"emit_refactor"}}
#      27 )
#
# File ~/anaconda3/envs/AutoFineTuner/lib/python3.10/site-packages/openai/_client.py:130, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     128     api_key = os.environ.get("OPENAI_API_KEY")
#     129 if api_key is None:
# --> 130     raise OpenAIError(
# ...
